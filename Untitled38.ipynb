# %% [markdown]
# <a href="https://colab.research.google.com/github/Rcoronetti/YoloV8/blob/main/Untitled38.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.6/646.6 kB 4.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task=segment mode=predict model=/content/yolov8n-seg.pt conf=0.25 source="/content/drive/MyDrive/VC/imagensVC/talheres.jpeg" save=True
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/drive/MyDrive/VC/imagensVC/talheres.jpeg: 480x640 2 forks, 1 knife, 1 toothbrush, 85.2ms
# Speed: 12.5ms preprocess, 85.2ms inference, 19.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image
Image('/content/runs/segment/predict/talheres.jpeg')
